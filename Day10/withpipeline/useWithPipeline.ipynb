# %% [markdown]
# ## Load Pipeline

# %%
import joblib
import pandas as pd

# %%
loaded_pipe = joblib.load(
    'titanic_pipeline.joblib'
)

# %% [markdown]
# ## Predict New Passenger

# %%
new_passenger = pd.DataFrame({
    "Pclass": [2],
    "Sex": ["male"],
    "Age": [31.0],
    "SibSp": [0],
    "Parch": [0],
    "Fare": [10.5],
    "Embarked": ["S"]
})

# %% [markdown]
# ## Prediction
# - pasanger will die

# %%
loaded_pipe.predict(
    new_passenger
)
# Out:
# array([0])

# %% [markdown]
# ## probability
# - die: 83%
# - not die: 16%

# %%
loaded_pipe.predict_proba(
    new_passenger
)
# Out:
# array([[0.83333333, 0.16666667]])
