# %% [markdown]
# # Playlist: 100 Days of ML
# 1. Working with Json

# %% [markdown]
# - downlaod kaggle API key & put it *`~/.kaggle/kaggle.json`*  location to download kaggle dataset with command line.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# - Listing datset with keyword ***`recipe ingredients`***

# %%
# !kaggle datasets list -s "recipe ingredients"
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication

# %% [markdown]
# - Downlaoding a dataset

# %%
# !kaggle datasets download -d kaggle/recipe-ingredients-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kaggle/recipe-ingredients-dataset
# License(s): unknown
# ...
# 100% 2.23M/2.23M [00:00<00:00, 129MB/s]

# %% [markdown]
# - Extracting the dataset from ziofile to normal filetype(JSON)

# %%
import zipfile
# !mkdir -p extracted_data
extracted_data = '/content/extracted_data'
with zipfile.ZipFile('/content/recipe-ingredients-dataset.zip', 'r') as f:
  f.extractall(extracted_data)

# !ls extracted_data/
# Out:
# test.json  train.json

# %%
import pandas as pd

pd.read_json('/content/extracted_data/test.json')
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]

# %% [markdown]
# - Reading the dataset using APIs

# %%
pd.read_json('https://restcountries.com/v3.1/all?fields=name,capital,currencies')
# Out:
#                                                   name  \
# 0    {'common': 'Anguilla', 'official': 'Anguilla',...
# 1    {'common': 'Guatemala', 'official': 'Republic ...
# 2    {'common': 'Gambia', 'official': 'Republic of ...
# 3    {'common': 'Mexico', 'official': 'United Mexic...
# 4    {'common': 'Malawi', 'official': 'Republic of ...
# ..                                                 ...
# 245  {'common': 'Central African Republic', 'offici...
# 246  {'common': 'Sudan', 'official': 'Republic of t...
# 247  {'common': 'Guinea-Bissau', 'official': 'Repub...
# 248  {'common': 'Papua New Guinea', 'official': 'In...
# 249  {'common': 'United States Minor Outlying Islan...
#
#                                             currencies           capital
# 0    {'XCD': {'name': 'Eastern Caribbean dollar', '...      [The Valley]
# 1    {'GTQ': {'name': 'Guatemalan quetzal', 'symbol...  [Guatemala City]
# 2           {'GMD': {'name': 'dalasi', 'symbol': 'D'}}          [Banjul]
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv').head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2. Working with SQL datasets

# %% [markdown]
# <p align="center">
#   <picture>
#     <source
#       srcset="https://github-readme-stats.vercel.app/api?username=pamit7d&show_icons=true&theme=tokyonight"
#       media="(prefers-color-scheme: dark)"
#     />
#
#     <source
#       srcset="https://github-readme-stats.vercel.app/api?username=pamit7d&show_icons=true&theme=default"
#       media="(prefers-color-scheme: light), (prefers-color-scheme: no-preference)"
#     />
#
#     <img
#       height="180em"
#       src="https://github-readme-stats.vercel.app/api?username=pamit7d&show_icons=true"
#     />
#   </picture>
# </p>

# %%
# !kaggle datasets download -d busielmorley/worldcities-pop-lang-rank-sql-create-tbls
# Out:
# Dataset URL: https://www.kaggle.com/datasets/busielmorley/worldcities-pop-lang-rank-sql-create-tbls
# License(s): world-bank
# ...
# 100% 89.9k/89.9k [00:00<00:00, 68.4MB/s]

# %% [markdown]
# # install XAMPP first, upload SQL database and then Run the following code in jupitar notebook.

# %%
# import mysql.connector

# conn = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     password="",
#     database="world"
# )

# print(conn)

# %%
# import pandas as pd

# pd.read_sql("SELECT * FROM city", conn)

# %% [markdown]
# ## Working with APIs

# %%
import pandas as pd

# %%
import http.client

conn = http.client.HTTPSConnection("indeed-scraper-api.p.rapidapi.com")

payload = "{\"scraper\":{\"maxRows\":15,\"query\":\"Developer\",\"location\":\"San Francisco\",\"jobType\":\"fulltime\",\"radius\":\"50\",\"sort\":\"relevance\",\"fromDays\":\"7\",\"country\":\"us\"}}"

headers = {
    'x-rapidapi-key': "b64c480237msh8ab652c8f37e954p1fff34jsn0e857e58d76f",
    'x-rapidapi-host': "indeed-scraper-api.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("POST", "/api/job", payload, headers)

res = conn.getresponse()
data = res.read()

# print(data.decode("utf-8"))

final_data = data.decode("utf-8")

# %%
import json
response = json.loads(final_data)
print(json.dumps(response, indent=2)[:50])
# Out:
# {
#   "state": "completed",
#   "meta": {
#     "max_row

# %%
print(type(response))
print(response.keys())
# Out:
# <class 'dict'>
# dict_keys(['state', 'meta', 'name', 'data', 'id', 'progress', 'returnvalue', 'delay', 'priority', 'attemptsStarted', 'attemptsMade', 'stalledCounter', 'timestamp', 'finishedOn', 'processedOn'])

# %%
# response['returnvalue']['data']

# %%
response['returnvalue']['data'][0].keys()
# Out:
# dict_keys(['jobKey', 'scrapingInfo', 'title', 'jobType', 'descriptionHtml', 'companyLogoUrl', 'descriptionText', 'companyName', 'companyUrl', 'companyHeaderUrl', 'location', 'salary', 'rating', 'benefits', 'occupation', 'attributes', 'contacts', 'shifts', 'socialInsurance', 'workingSystem', 'shiftAndSchedule', 'postedToday', 'hiringDemand', 'datePublished', 'expired', 'source', 'age', 'isRemote', 'locale', 'language', 'jobUrl', 'applyUrl', 'emails', 'companyIndustry', 'companyAddresses', 'companyNumEmployees', 'companyRevenue', 'companyDescription', 'companyFounded', 'companyLinks', 'companyCeo', 'requirements'])

# %%
a = pd.DataFrame(response['returnvalue']['data'])
a.shape
# Out:
# (15, 44)

# %%
a.head()
# Out:
#              jobKey             scrapingInfo  \
# 0  d68a1b07ae3ac1e2  {'page': 1, 'index': 6}
# 1  1edbedada46a970f  {'page': 1, 'index': 9}
# 2  a23c086e4df1f983  {'page': 1, 'index': 0}
# 3  76ac8d7e5e2bebb7  {'page': 1, 'index': 1}
# 4  d085666277315020  {'page': 1, 'index': 2}
#
#                                                title      jobType  \
# 0  NPI Product Manager-Power Supply /Hardware ( M...  [Full-time]
# 1        AI Infrastructure Engineer, Digital Optimus  [Full-time]
# 2  Software Engineer III - Java Full Stack Developer  [Full-time]
# 3     Java Full Stack Developer-Software Engineer II  [Full-time]
# 4            Lead Full Stack Engineer PxE Consulting  [Full-time]
#
#                                      descriptionHtml  \
# 0  <p><b>About Us:</b></p><p>MEAN WELL USA is a s...
# 1  <div><b>What to Expect</b><div>\nDigital Optim...
# 2  <div>Are you an experienced, passionate pionee...
# 3  <div>Are you an experienced, passionate pionee...
# ...
